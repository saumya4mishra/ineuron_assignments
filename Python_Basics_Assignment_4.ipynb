# %% [raw]
# 1. What exactly is []?
#
# [] is called square brackets which in python is mainly used to define list data types such as
#
# mylist = [1, 2, 3, 4, 5]
#
# above statement defines a list.
#
# [] is also used to access data from lists, dictionaries, and tuples.
#
# mylist[2]
# >> 3
#
# its even used in slicing opertaions
# mylist[0:2]
# >> [1, 2]
#
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2,    4, 6, 8, 10] are in spam.)
#
# my_list = [2, 4, 6, 8, 10]
# my_list.insert(2, 'hello')
#
#
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# >> 'd'
#
# 4. What is the value of spam[-1]?
#
# >> 'd'
#
# 5. What is the value of spam[:2]?
# >>  ['a', 'b']
#
#
#
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
# 6. What is the value of bacon.index('cat')?
#
# synatx error in
# bacon = [3.14, 'cat,' 11, 'cat,' True]
#
# assuming correct syntax output would be
#
# >> 1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# >> [3.14, 'cat', 11, 'cat', True, 99]
#
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
#
# >> [3.14, 11, 'cat', True, 99]
#
# remove() function removes the first occurances of in the list
#
#
# 9. What are the list concatenation and list replication operators?
#
# name = 'SAM'
#
# name + name
# >> 'SAMSAM'
# above opertaion is list concatenation
#
# name*3
# >> 'SAMSAMSAM'
# above operation is list replication
#
#
# 10. What is difference between the list methods append() and insert()?
#
# mlist = [1, 2, 3, 4, 5]
#
# append is used to add values to a list but only at the last index
# so,
# mlist.append(6)
#
# >> [1, 2, 3, 4, 5, 6]
#
# whereas,
#
# using insert we can insert a value at any given instance therefore the values at instances greater than the given instance will shift one step forward
#
# mlist.insert(2, 7)
#
# >> [1, 2, 7, 3, 4, 5, 6]
#
#
# 11. What are the two methods for removing items from a list?
#
# method 1:  using remove() function, here we need to give the value that needs to be removed from the list, it removes the first occurance of that value in that list
#
# mlist.remove(7)
# >> [1, 2, 3, 4, 5, 6]
#
# method 2: using pop() function, here we need to provide the index of the value that needs to be removed. by default the last value is removed.
#
# mlist.pop(2)
# >> [1, 2, 4, 5, 6]
#
#
# 12. Describe how list values and string values are identical.
#
# list and string data type are quite identical. on one hand string is a lists are collection of bytes representing unicode characters whereas list is a collection of heterogeneous data types.
#
# both lists and string support concatenation and replication opertaions
# both support slicing operations
#
#
#
# 13. What's the difference between tuples and lists?
#
# major difference between lists and tuples is that lists are muable collection of heterogeneous data whereas, tuples are immutable. In simpler terms, data in lists can be modifies on the other hand its not possible for tuples.
#
# list are defined using [], whereas tuples are defined using ()
#
#
#
# 14. How do you type a tuple value that only contains the integer 42?
#
# mtuple = (42,)
#
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# mtuple = (1, 2, 3, 4, 5)
#
# mlist = list(mtuple)
#
# mtuple_new = tuple(mlist)
#
# ### we can use list() function to convert an iterable data type into list whereas,
#     tuple() is used to convert an iterable into tuple
#
#
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
# When you assign a list to a variable, you are actually assigning a list reference to the variable. A reference is a value that points to some bit of data, and a list reference is a value that points to a list.
#
# >>> spam = [0, 1, 2, 3, 4, 5]
# >>> cheese = spam
# >>> cheese[1] = 'Hello!'
# >>> spam
# [0, 'Hello!', 2, 3, 4, 5]
# >>> cheese
# [0, 'Hello!', 2, 3, 4, 5]
#
#
# here we can see any changes made in cheese variable also reflects in spam.
#
# When you create the list, you assign a reference to it in the spam variable. But the next line copies only the list reference in spam to cheese, not the list value itself. This means the values stored in spam and cheese now both refer to the same list.
#
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# >>> import copy
# >>> spam = ['A', 'B', 'C', 'D']
# >>> cheese = copy.copy(spam)
# >>> cheese[1] = 42
# >>> spam
# ['A', 'B', 'C', 'D']
# >>> cheese
# ['A', 42, 'C', 'D']
#
#  copy.copy(), can be used to make a duplicate copy of a mutable value like a list or dictionary, not just a copy of a reference. Now the spam and cheese variables refer to separate lists, which is why only the list in cheese is modified when you assign 42 at index 1.
#
# If the list you need to copy contains lists, then use the copy.deepcopy() function instead of copy.copy(). The deepcopy() function will copy these inner lists as well.
