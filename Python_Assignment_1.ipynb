# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *          Expression, this is a mathematical operator for multiplication
# 'hello'    Value, this is a string value
# -87.8      Value, this is a float value
# -          Expression, this is a mathematical operator for subtraction
# /          Expression, this is a mathematical operator for subtraction
# +          Expression, this is a mathematical operator for Addition
# 6          Value, this is an  integer value
#
#
#
# 2. What is the difference between string and variable?
#
# String is a data type which are arrays of bytes representing Unicode characters such as 'saumya', "ineuron"
#
# Variable is the named reference to the memory loaction where data is stored suc as   my_name = 'saumya'
#
# so, my_name is the reference using which I can access my data i.e 'saumya'
#
# here 'saumya' is a type of data which is string
#
#
# 3. Describe three different data types.
#
# String: String is a data type which are arrays of bytes representing Unicode characters such as 'saumya', "ineuron"
#
# strings are enclosed inside single or double colens 'saumya' or "mishra"
#
# strings are immutable which means we cannot modify the value of a string
#
# my_name = 'saumya'
# my_name[2] = 'k'
#
# this will give error that strings are immutable
#
# List: List is a data type which is a collection of heterogeneous data, lists are mutable i.e elements of the lists can be  modeified as and when required. e.g
#
# l_mylist = ['name', 1234, 3 + 4j, True, 40.9887]
#
# The above data type is a list which are always enclosed between square braces []. It can hold multiple data types with mutability
#
# Sets: Set is an unordered collection of data type that is iterable, mutable and has no duplicate elements. The order of elements in a set is undefined though it may consist of various elements.
#
# sets are enclosed inside curved brackets {}
# sets are iteratable but we cannot do slicing on sets
# sets are even unordered
# sets has no duplicate elements
#
# st_myset = { 1, 2, 2, 3, 4, 5, 5, 'mish', 'mish', 8}
#
# print(st_myset)
#
# O/P: {1, 2, 3, 4, 5, 'mish', 8}
#
#
# 4. What is an expression made up of? What do all expressions do?
#
# In python, an expression is any legal combination of symbols (like a variable, constants, and operators) representing a value. An expression must have at least one operand (variable or constant) and have one or more operators. After evaluating an expression, we get a value as output.
#
# For example, x+y*z-8 is an example of an expression, where +, * are operators; x, y, and z are variables, and 8 is a constant.
#
# Actually, the operand is the value on which the operator is applied, and operators use constants and variables to form an expression.
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Expressions only contain identifiers, literals and operators, where operators include arithmetic and boolean operators, the function call operator () the subscription operator [] and similar. The output of an expression is some kind of "value", which can be any Python object. Examples:
#
# 3 + 5
# map(lambda x: x*x, range(10))
# [a.x for a in some_iterable]
# yield 7
#
# Statements on the other hand, are everything that can make up a line (or several lines) of Python code. Note that expressions are statements as well. Examples:
#
# print 42
# if x: do_y()
# return
# a = 7
#
# 6. 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
#
# bacon still contains 22 since bacon + 1 is not assigned to bacon itself however
# if the 2nd statement would've been
#
# bacon = bacon + 1
#
# then bacon would contain 23
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# 'spam' + 'spamspam'
# O/P = 'spamspamspam'
#
# 'spam' * 3
# O/P = 'spamspamspam'
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# every variable defined must follow the below rules:
#
# A variable name must start with a letter or the underscore character.
# A variable name cannot start with a number.
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# Variable names are case-sensitive (name, Name and NAME are three different variables).
# The reserved words (keywords) cannot be used naming the variable.
#
#
# eggs is a valid variable name since it follows the above rules while,
#
# 100 does not follow them since it starts with a number.
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# a  = 10.98
# print(int(a))
# print(type(int(a)))
# O/P  10
#     <class 'int'>
#
#     in above code int() is a function which converts the input value to an integer
#
# a = 100
# print(float(a))
# print(type(float(a)))
# O/P  100.0
#     <class 'float'>
#
#     in above code float() is a function which converts the input value to a float
#
# s = 100
# print(string(a))
# print(type(string(a)))
# O/P  '100'
#     <class 'str'>
#
#     in above code str() is a function which converts the input value to a string
#
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# the above statement gives the following error
#
# can only concatenate str (not "int") to str
#
# thats because we cannot concatenate heregeneous data types like string 'I have eaten ' to integer  99
#
# to solve it we must explcitly convert 99 to string using str() funtion
#
# 'I have eaten ' + str(99) + ' burritos.'
